# %%
def greet2(name):#A function with a single parmeter or argument
    return f'Welcome to python class {name}'
print(greet2('Ade'))
# Out:
# Welcome to python class Ade

# %%
def bag_check(type_of_bag,color,bagweight):
    if bagweight <= 23:
        print('Normal bag weight no charges')
    elif bagweight >=24 and bagweight <=30:
        print('Above normal bag weight by little kg therefore you will be charged N10,000')
    elif bagweight >=31 and bagweight <=40:
        print('Above normal bag weight by meduim kg therefore you will be charged N20,000')
    else:
        print('Above normal bag weight by large kg therefore you will be charged N40,000')
print(bag_check('Meduim Box','Black',59))
# Out:
# Above normal bag weight by large kg therefore you will be charged N40,000
# None

# %%
def dice_roller():
    import random
    player1score = 0
    player2score = 0
    for i in range(1,11):
        dice1 = random.randint(1,6) + random.randint(1,6)
        dice2 = random.randint(1,6) + random.randint(1,6)
        
        if dice1 > dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER ONE WINS')
            player1score = player1score + 5
            print('\n')
        elif dice2 > dice1:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER TWO WINS')
            player2score = player1score + 5
        elif dice1 == dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'IT IS A DRAW')
            player1score = player1score + 2
            player1score = player1score + 2
            print('\n')
    if player1score > player2score:
        print(f'PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF{player1score}')
    elif player2score > player1score:
            print(f'PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF{player2score}')
    else:
            print('NO WINNER THERFORE IT IS A DRAW')
dice_roller()
# Out:
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 8
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# NO WINNER THERFORE IT IS A DRAW

# %%
def dice_roller():
    import random
    player1score = 0
    player2score = 0
    counter = 1
    while counter <= 10:
        dice1 = random.randint(1,6) + random.randint(1,6)
        dice2 = random.randint(1,6) + random.randint(1,6)
        
        if dice1 > dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER ONE WINS')
            player1score = player1score + 5
            print('\n')
        elif dice2 > dice1:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER TWO WINS')
            player2score = player1score + 5
        elif dice1 == dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'IT IS A DRAW')
            player1score = player1score + 2
            player1score = player1score + 2
            print('\n')
            counter += 1
    if player1score > player2score:
        print(f'PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF{player1score}')
    elif player2score > player1score:
            print(f'PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF{player2score}')
    else:
            print('NO WINNER THERFORE IT IS A DRAW')
dice_roller()
# Out:
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 9
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 11
# PLAYER TWO WINS
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 10
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 4
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 2
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 10
# PLAYER TWO WINS
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 12
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 6
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 12
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 6
# PLAYER TWO WINS
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 10
# PLAYER TWO WINS
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 12
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 11
# PLAYER TWO WINS
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 9
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 10
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 2
# PLAYER TWO SCORE 6
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 10
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 10
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 11
# PLAYER TWO WINS
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 3
# PLAYER TWO SCORE 6
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 10
# PLAYER TWO WINS
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 10
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 2
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 3
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 8
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 8
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 2
# PLAYER TWO SCORE 3
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 6
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 11
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 11
# PLAYER TWO WINS
# PLAYER ONE SCORE 3
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 9
# PLAYER TWO WINS
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 4
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 7
# PLAYER TWO WINS
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 8
# PLAYER TWO WINS
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 9
# IT IS A DRAW
#
#
# PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF340

# %%
def average(*num):
    print(type(num))
    avg = sum(num)/len(num)
    return avg
average(47,89,56,85,24,69,87,89,63,25)
# Out:
# <class 'tuple'>
# 63.4

# %%
def average(*num):
    print(type(num))
    avg = sum(num)/len(num)
    return f'The average score of the following numbers {num} is {avg}'
average(47,89,56,85,24,69,87,89,63,25)
# Out:
# <class 'tuple'>
# 'The average score of the following numbers (47, 89, 56, 85, 24, 69, 87, 89, 63, 25) is 63.4'

# %%
import random
numbers = []
counter = 1
while counter<= 50:
    numbers.append(random.randint(45,80))
    counter += 1
print(numbers)
# Out:
# [48, 80, 48, 65, 61, 79, 73, 54, 57, 80, 58, 54, 54, 46, 60, 70, 71, 71, 53, 56, 57, 69, 61, 58, 55, 51, 75, 70, 75, 80, 67, 51, 49, 80, 79, 63, 48, 61, 59, 46, 54, 45, 73, 53, 70, 67, 78, 63, 77, 78]

# %%
average(*numbers)
# Out:
# <class 'tuple'>
# 'The average score of the following numbers (48, 80, 48, 65, 61, 79, 73, 54, 57, 80, 58, 54, 54, 46, 60, 70, 71, 71, 53, 56, 57, 69, 61, 58, 55, 51, 75, 70, 75, 80, 67, 51, 49, 80, 79, 63, 48, 61, 59, 46, 54, 45, 73, 53, 70, 67, 78, 63, 77, 78) is 63.0'

# %%
def details(**record):
    print(type(record))
    for key, value in record.items():
        print(f'{key} ::: {value}')
details(name= 'Ade',age=45,gender='Male')
# Out:
# <class 'dict'>
# name ::: Ade
# age ::: 45
# gender ::: Male

# %%
bmi = (w/(h**2)) #metric formula. #annonymous function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 bmi = (w/(h**2))
#
# NameError: name 'w' is not defined
